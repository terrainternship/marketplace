# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = '/content/drive/MyDrive/trainee/Ingate/Ozon/Аналитика Графики 01.06.2022-31.05.2023.xlsx'
df = pd.read_excel(path)
df.head()
# Out:
#        Категория 3-го уровня                         Товары  \
# 0  Разное автопринадлежности  Светодиодная подсветка салона
# 1  Разное автопринадлежности  Светодиодная подсветка салона
# 2  Разное автопринадлежности  Светодиодная подсветка салона
# 3  Разное автопринадлежности  Светодиодная подсветка салона
# 4  Разное автопринадлежности  Светодиодная подсветка салона
#
#                           Модель    Ozon ID Артикул        День  \
# 0  Светодиодная подсветка салона  882353426   34414  2023-03-03
# 1  Светодиодная подсветка салона  882353426   34414  2023-03-05
# 2  Светодиодная подсветка салона  882353427   34414  2023-03-05
# 3  Светодиодная подсветка салона  882353427   34414  2023-03-06
# 4  Светодиодная подсветка салона  882353427   34414  2023-03-07
#
#    Уникальные посетители, всего  \
# 0                             1
# 1                             1
# 2                            65
# 3                            85
# 4                            44
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 254748 entries, 0 to 254747
# Data columns (total 19 columns):
#  #   Column                                                 Non-Null Count   Dtype
# ---  ------                                                 --------------   -----
#  0   Категория 3-го уровня                                  254748 non-null  object
#  1   Товары                                                 254748 non-null  object
#  2   Модель                                                 211411 non-null  object
#  3   Ozon ID                                                254748 non-null  int64
#  4   Артикул                                                254748 non-null  object
#  5   День                                                   254748 non-null  object
#  6   Уникальные посетители, всего                           254748 non-null  int64
#  7   Уникальные посетители с просмотром карточки товара     254748 non-null  int64
# ...

# %%
df['Категория 3-го уровня'].value_counts()
# Out:
# Комплектующие для ксеноновых фар             150270
# Фара автомобильная                            90891
# Лампа автомобильная                           11585
# Автохимия - Герметик, клей                     1255
# Фонарь задний для авто                          399
# Светодиодный модуль                             233
# Разное автопринадлежности                        90
# Другое                                           18
# Комплектующие светодиодной лампы для авто         4
# Противотуманные фары                              3
# Name: Категория 3-го уровня, dtype: int64

# %%
df['Категория 3-го уровня'].nunique()
# Out:
# 10

# %%
df['Товары'].nunique()
# Out:
# 998

# %%
df['Модель'].nunique()
# Out:
# 862

# %%
df['Ozon ID'].nunique()
# Out:
# 1233

# %%
df['Артикул'].nunique()
# Out:
# 994

# %%
ls_nnum = [nn for nn in df['Артикул'].unique() if not nn.isdigit()]
ls_nnum
# Out:
# ['FL10NS', 'FL10VW', 'FL25W', '2A50']

# %%
df.describe()
# Out:
#             Ozon ID  Уникальные посетители, всего  \
# count  2.547480e+05                 254748.000000
# mean   5.454499e+08                     49.647157
# std    8.758402e+07                    220.228001
# min    2.609023e+08                      0.000000
# 25%    5.106627e+08                      4.000000
# 50%    5.115731e+08                     10.000000
# 75%    5.784897e+08                     30.000000
# max    9.660743e+08                  12798.000000
#
#        Уникальные посетители с просмотром карточки товара  Показы, всего  \
# count                                      254748.000000   254748.000000
# mean                                            1.861180       87.889228
# std                                             9.179129      416.146915
# min                                             0.000000        0.000000
# 25%                                             0.000000        5.000000
# ...

# %%
df.to_csv('/content/drive/MyDrive/trainee/Ingate/Ozon/data_ozon.csv', index=False)
